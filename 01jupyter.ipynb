# %% [markdown]
# # unordered list
#
# * item 1
# * item 2
#    * sublist 1
#    * sublist 2

# %% [markdown]
# # this is first jupyter program

# %%
print("dipok")
print("ok")

# %% [markdown]
# # orderd list
# 1. item 1
# 2. item 2
#     1. sub item 1
#     2. sub item 2
#          1. sub sub item1
#          2. sub sub item 2
#               1. sub sub sub item1
#               2. sub sub sub item 2

# %% [markdown]
# # Latex equation
# $e^{i\lambda} + \pi = 0$
#
# $$e^x=\sum_{i=\gamma}^\theta \frac{1}{i!}x^i$$
