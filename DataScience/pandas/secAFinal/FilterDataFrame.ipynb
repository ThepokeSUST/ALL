# %%
# import module
import pandas as pd

# assign data
dataFrame = pd.DataFrame({'Name': [' RACHEL  ', ' MONICA  ', ' PHOEBE  ',
                                   '  ROSS    ', 'CHANDLER', ' JOEY    '],
                          
                          'Age': [30, 35, 37, 33, 34, 30],
                          
                          'Salary': [100000, 93000, 88000, 120000, 94000, 95000],
                          
                          'JOB': ['DESIGNER', 'CHEF', 'MASUS', 'PALENTOLOGY',
                                  'IT', 'ARTIST']})

# display dataframe
display(dataFrame)
df=dataFrame
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST

# %%
f=df[['Age']]>30
print(f,type(f))
print(df[f])
print()
f=df['Age']>30
print(f,type(f))
print(df[f])
print()



# row=df.loc[]
# print(row)
# Out:
#      Age
# 0  False
# 1   True
# 2   True
# 3   True
# 4   True
# 5  False <class 'pandas.core.frame.DataFrame'>
#   Name   Age  Salary  JOB
# 0  NaN   NaN     NaN  NaN
# 1  NaN  35.0     NaN  NaN
# 2  NaN  37.0     NaN  NaN
# 3  NaN  33.0     NaN  NaN
# 4  NaN  34.0     NaN  NaN
# 5  NaN   NaN     NaN  NaN
#
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# Name: Age, dtype: bool <class 'pandas.core.series.Series'>
#          Name  Age  Salary          JOB
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
#
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# Name: Age, dtype: bool

# %%
print(df)
f1= df['Salary']>90000
f2=df['Age']>30  
print(f1,f2)
print(f1&f2)

print(type(f2))
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# Name: Salary, dtype: bool 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# Name: Age, dtype: bool
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool
# <class 'pandas.core.series.Series'>

# %%
print(df)
f2=df[['Salary','Age']]>30
print(f2)
print(df[f2])
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST
#    Salary    Age
# 0    True  False
# 1    True   True
# 2    True   True
# 3    True   True
# 4    True   True
# 5    True  False
#   Name   Age  Salary  JOB
# 0  NaN   NaN  100000  NaN
# 1  NaN  35.0   93000  NaN
# 2  NaN  37.0   88000  NaN
# 3  NaN  33.0  120000  NaN
# 4  NaN  34.0   94000  NaN
# 5  NaN   NaN   95000  NaN

# %%
print(df)
lst=[[True,False,False,True],
     [True,False,True,True],
     [False,False,False,False],
     [False,False,False,True],
     [True,True,False,True],
     [True,False,False,True],
     [True,False,False,True]]
df2=pd.DataFrame(lst)
print(df2)
print(df[df2])
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST
#        0      1      2      3
# 0   True  False  False   True
# 1   True  False   True   True
# 2  False  False  False  False
# 3  False  False  False   True
# 4   True   True  False   True
# 5   True  False  False   True
# 6   True  False  False   True
#   Name  Age  Salary  JOB
# 0  NaN  NaN     NaN  NaN
# 1  NaN  NaN     NaN  NaN
# 2  NaN  NaN     NaN  NaN
# 3  NaN  NaN     NaN  NaN
# 4  NaN  NaN     NaN  NaN
# 5  NaN  NaN     NaN  NaN

# %%
df2.rename(columns={0:'Name'},inplace=True)
print(df2)
print(df[df2])
# Out:
#     Name      1      2      3
# 0   True  False  False   True
# 1   True  False   True   True
# 2  False  False  False  False
# 3  False  False  False   True
# 4   True   True  False   True
# 5   True  False  False   True
# 6   True  False  False   True
#         Name  Age  Salary  JOB
# 0   RACHEL    NaN     NaN  NaN
# 1   MONICA    NaN     NaN  NaN
# 2        NaN  NaN     NaN  NaN
# 3        NaN  NaN     NaN  NaN
# 4   CHANDLER  NaN     NaN  NaN
# 5   JOEY      NaN     NaN  NaN

# %%
print(df)
# print(df2)
df2.index=[0,1,6,3,4,5,2]
print(df2)
print(df[df2])
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST
#     Name      1      2      3
# 0   True  False  False   True
# 1   True  False   True   True
# 6  False  False  False  False
# 3  False  False  False   True
# 4   True   True  False   True
# 5   True  False  False   True
# 2   True  False  False   True
#         Name  Age  Salary  JOB
# 0   RACHEL    NaN     NaN  NaN
# 1   MONICA    NaN     NaN  NaN
# 2   PHOEBE    NaN     NaN  NaN
# 3        NaN  NaN     NaN  NaN
# 4   CHANDLER  NaN     NaN  NaN
# 5   JOEY      NaN     NaN  NaN

# %%
lst=[True,False,True]
df2=pd.DataFrame(lst)
print(df2)

df2.rename(columns={0:'Age'},inplace=True)
print(df[df2])

# error
# lst=[True,2,3]
# df2=pd.DataFrame(lst)
# print(df2)
# df2.rename(columns={0:'Name'},inplace=True)
# print(df[df2])
# Out:
#        0
# 0   True
# 1  False
# 2   True
#   Name   Age  Salary  JOB
# 0  NaN  30.0     NaN  NaN
# 1  NaN   NaN     NaN  NaN
# 2  NaN  37.0     NaN  NaN
# 3  NaN   NaN     NaN  NaN
# 4  NaN   NaN     NaN  NaN
# 5  NaN   NaN     NaN  NaN

# %%
print(df)
filter1=df['Age']>30
print(filter1,type(filter1))
print(df[filter1])

filter2=df[['Age']]>30
# print(filter2)
print(df[filter2])
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# Name: Age, dtype: bool <class 'pandas.core.series.Series'>
#          Name  Age  Salary          JOB
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
#   Name   Age  Salary  JOB
# 0  NaN   NaN     NaN  NaN
# 1  NaN  35.0     NaN  NaN
# 2  NaN  37.0     NaN  NaN
# 3  NaN  33.0     NaN  NaN
# 4  NaN  34.0     NaN  NaN
# 5  NaN   NaN     NaN  NaN

# %%
print(filter2)
# Out:
#      Age
# 0  False
# 1   True
# 2   True
# 3   True
# 4   True
# 5  False

# %%
print(df)
df.index=['a','b','c','d','e','f']
f= (df['Age']>10) & (df['Salary']>90000)
print(f)
print(df[f])
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST
# a     True
# b     True
# c    False
# d     True
# e     True
# f     True
# dtype: bool
#          Name  Age  Salary          JOB
# a    RACHEL     30  100000     DESIGNER
# b    MONICA     35   93000         CHEF
# d    ROSS       33  120000  PALENTOLOGY
# e    CHANDLER   34   94000           IT
# f    JOEY       30   95000       ARTIST

# %%
print(df)
q=df.query('Age>30 & Salary>90000')
print(q,type(q))
print(q[['Age','JOB']])

print(df.query('Age>30')[['JOB']])
# Out:
#          Name  Age  Salary          JOB
# a    RACHEL     30  100000     DESIGNER
# b    MONICA     35   93000         CHEF
# c    PHOEBE     37   88000        MASUS
# d    ROSS       33  120000  PALENTOLOGY
# e    CHANDLER   34   94000           IT
# f    JOEY       30   95000       ARTIST
#          Name  Age  Salary          JOB
# b    MONICA     35   93000         CHEF
# d    ROSS       33  120000  PALENTOLOGY
# e    CHANDLER   34   94000           IT <class 'pandas.core.frame.DataFrame'>
#    Age          JOB
# b   35         CHEF
# d   33  PALENTOLOGY
# e   34           IT
#            JOB
# b         CHEF
# c        MASUS
# d  PALENTOLOGY
# e           IT

# %%
print(df)
isin=df['Age'].isin([30])
print(isin,type(isin))
print(df[isin])
# Out:
#          Name  Age  Salary          JOB
# a    RACHEL     30  100000     DESIGNER
# b    MONICA     35   93000         CHEF
# c    PHOEBE     37   88000        MASUS
# d    ROSS       33  120000  PALENTOLOGY
# e    CHANDLER   34   94000           IT
# f    JOEY       30   95000       ARTIST
# a     True
# b    False
# c    False
# d    False
# e    False
# f     True
# Name: Age, dtype: bool <class 'pandas.core.series.Series'>
#         Name  Age  Salary       JOB
# a   RACHEL     30  100000  DESIGNER
# f   JOEY       30   95000    ARTIST
#      Age
# a   True
# b  False
# c  False
# d  False
# e  False
# f   True <class 'pandas.core.frame.DataFrame'>
#   Name   Age  Salary  JOB
# a  NaN  30.0     NaN  NaN
# b  NaN   NaN     NaN  NaN
# c  NaN   NaN     NaN  NaN
# d  NaN   NaN     NaN  NaN
# e  NaN   NaN     NaN  NaN
# f  NaN  30.0     NaN  NaN

# %%
isin=df[['Age']].isin([30])
print(isin,type(isin))
print(df[isin])

isin=df[['Age','Salary']].isin([30])
print(isin,type(isin))
print(df[isin])
# Out:
#      Age
# a   True
# b  False
# c  False
# d  False
# e  False
# f   True <class 'pandas.core.frame.DataFrame'>
#   Name   Age  Salary  JOB
# a  NaN  30.0     NaN  NaN
# b  NaN   NaN     NaN  NaN
# c  NaN   NaN     NaN  NaN
# d  NaN   NaN     NaN  NaN
# e  NaN   NaN     NaN  NaN
# f  NaN  30.0     NaN  NaN
#      Age  Salary
# a   True   False
# b  False   False
# c  False   False
# d  False   False
# e  False   False
# f   True   False <class 'pandas.core.frame.DataFrame'>
#   Name   Age  Salary  JOB
# a  NaN  30.0     NaN  NaN
# b  NaN   NaN     NaN  NaN
# c  NaN   NaN     NaN  NaN
# d  NaN   NaN     NaN  NaN
# e  NaN   NaN     NaN  NaN
# f  NaN  30.0     NaN  NaN

# %% [markdown]
# # Query and eval

# %%
print(df)
wage=90000
print()
print(df.query('Age>30 & Salary>@wage'))
print()
print(df.eval('Age>30 & Salary>@wage'))
print(df[df.eval('Age>30 & Salary>@wage')])
# Out:
#          Name  Age  Salary          JOB
# a    RACHEL     30  100000     DESIGNER
# b    MONICA     35   93000         CHEF
# c    PHOEBE     37   88000        MASUS
# d    ROSS       33  120000  PALENTOLOGY
# e    CHANDLER   34   94000           IT
# f    JOEY       30   95000       ARTIST
#
#          Name  Age  Salary          JOB
# b    MONICA     35   93000         CHEF
# d    ROSS       33  120000  PALENTOLOGY
# e    CHANDLER   34   94000           IT
#
# a    False
# b     True
# c    False
# d     True
# e     True
# f    False
# dtype: bool
#          Name  Age  Salary          JOB
# b    MONICA     35   93000         CHEF
# d    ROSS       33  120000  PALENTOLOGY
# e    CHANDLER   34   94000           IT
