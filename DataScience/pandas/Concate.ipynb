# %%
import pandas as pd

data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}

df = pd.DataFrame(data1, index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])

print(df, "\n\n", df1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
frames=[df,df1]
res=pd.concat(frames)
# print(res)

df1['newcol']=[1,2,3,4]
print()
print()
print(df1)
print()
print(frames[1])
print(res)
# Out:
#      Name  Age    Address Qualification  newcol
# 4    Abhi   17     Nagpur         Btech       1
# 5  Ayushi   14     Kanpur           B.A       2
# 6  Dhiraj   12  Allahabad          Bcom       3
# 7  Hitesh   52    Kannuaj        B.hons       4
#
#      Name  Age    Address Qualification  newcol
# 4    Abhi   17     Nagpur         Btech       1
# 5  Ayushi   14     Kanpur           B.A       2
# 6  Dhiraj   12  Allahabad          Bcom       3
# 7  Hitesh   52    Kannuaj        B.hons       4
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
frames=[df,df1,df]
res1=pd.concat(frames)
print(res1)
# Out:
#      Name  Age    Address Qualification  newcol
# 0     Jai   27     Nagpur           Msc     NaN
# 1  Princi   24     Kanpur            MA     NaN
# 2  Gaurav   22  Allahabad           MCA     NaN
# 3    Anuj   32    Kannuaj           Phd     NaN
# 4    Abhi   17     Nagpur         Btech     1.0
# 5  Ayushi   14     Kanpur           B.A     2.0
# 6  Dhiraj   12  Allahabad          Bcom     3.0
# 7  Hitesh   52    Kannuaj        B.hons     4.0
# 0     Jai   27     Nagpur           Msc     NaN
# 1  Princi   24     Kanpur            MA     NaN
# 2  Gaurav   22  Allahabad           MCA     NaN
# 3    Anuj   32    Kannuaj           Phd     NaN

# %%
print(res1.loc[0])
# Out:
#   Name  Age Address Qualification  newcol
# 0  Jai   27  Nagpur           Msc     NaN
# 0  Jai   27  Nagpur           Msc     NaN

# %%
res2=pd.concat(frames,axis=1)
print('.......')
print(res2)
print('.......')
# Out:
# .......
#      Name   Age    Address Qualification    Name   Age    Address  \
# 0     Jai  27.0     Nagpur           Msc     NaN   NaN        NaN
# 1  Princi  24.0     Kanpur            MA     NaN   NaN        NaN
# 2  Gaurav  22.0  Allahabad           MCA     NaN   NaN        NaN
# 3    Anuj  32.0    Kannuaj           Phd     NaN   NaN        NaN
# 4     NaN   NaN        NaN           NaN    Abhi  17.0     Nagpur
# 5     NaN   NaN        NaN           NaN  Ayushi  14.0     Kanpur
# 6     NaN   NaN        NaN           NaN  Dhiraj  12.0  Allahabad
# 7     NaN   NaN        NaN           NaN  Hitesh  52.0    Kannuaj
#
#   Qualification  newcol    Name   Age    Address Qualification
# 0           NaN     NaN     Jai  27.0     Nagpur           Msc
# 1           NaN     NaN  Princi  24.0     Kanpur            MA
# 2           NaN     NaN  Gaurav  22.0  Allahabad           MCA
# 3           NaN     NaN    Anuj  32.0    Kannuaj           Phd
# 4         Btech     1.0     NaN   NaN        NaN           NaN
# 5           B.A     2.0     NaN   NaN        NaN           NaN
# 6          Bcom     3.0     NaN   NaN        NaN           NaN
# 7        B.hons     4.0     NaN   NaN        NaN           NaN
# .......

# %% [markdown]
# ## query

# %%
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}

df=pd.DataFrame(data1)
df1=pd.DataFrame(data2)
print(df)
print()
print(df1)
print()
print(df1.query('Age>14 & Address.str.endswith("r")'))
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#      Name  Age    Address Qualification
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad          Bcom
# 3  Hitesh   52    Kannuaj        B.hons
#
#    Name  Age Address Qualification
# 0  Abhi   17  Nagpur         Btech
