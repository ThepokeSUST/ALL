# %% [markdown]
# ## create

# %%
import pandas as pd
import numpy as np
ser = pd.Series()

print(ser)
# Out:
# Series([], dtype: object)

# %%
data = np.array(['g', 'e', 'e', 'k', 's'])

ser = pd.Series(data)
print(ser)
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
lst=[2,3,4,5]
ser=pd.Series(lst)
print(ser)
ser=pd.Series(np.array([2,3,4,5]))
print(ser)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64
