# %% [markdown]
# ## multiple condition

# %%
import pandas as pd

# assign data
dataFrame = pd.DataFrame({'Name': [' RACHEL  ', ' MONICA  ', ' PHOEBE  ',
                                   '  ROSS    ', 'CHANDLER', ' JOEY    '],
                          
                          'Age': [30, 35, 37, 33, 34, 30],
                          
                          'Salary': [100000, 93000, 88000, 120000, 94000, 95000],
                          
                          'JOB': ['DESIGNER', 'CHEF', 'MASUS', 'PALENTOLOGY',
                                  'IT', 'ARTIST']})

print(dataFrame)

# display("ok","hello")
display(dataFrame)
# Out:
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST
#          Name  Age  Salary          JOB
# 0    RACHEL     30  100000     DESIGNER
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
# 5    JOEY       30   95000       ARTIST

# %%
dataFrame = pd.DataFrame({'Name': [' RACHEL  ', ' MONICA  ', ' PHOEBE  ',
                                   '  ROSS    ', 'CHANDLER', ' JOEY    '],
                          
                          'Age': [30, 35, 37, 33, 34, 30],
                          
                          'Salary': [100000, 93000, 88000, 120000, 94000, 95000],
                          
                          'JOB': ['DESIGNER', 'CHEF', 'MASUS', 'PALENTOLOGY',
                                  'IT', 'ARTIST']})

print(dataFrame[dataFrame['Age']>30])

print(dataFrame.loc[ dataFrame['Age']>30,:'Age'])
d=(dataFrame['Age']>30)&(dataFrame['Salary']>90000)
print(d,type(d))

print("................................")
print(dataFrame[d])
print(dataFrame.loc[d,:'Salary'])
# Out:
#          Name  Age  Salary          JOB
# 1    MONICA     35   93000         CHEF
# 2    PHOEBE     37   88000        MASUS
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
#          Name  Age
# 1    MONICA     35
# 2    PHOEBE     37
# 3    ROSS       33
# 4    CHANDLER   34
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool <class 'pandas.core.series.Series'>
# ................................
#          Name  Age  Salary          JOB
# 1    MONICA     35   93000         CHEF
# 3    ROSS       33  120000  PALENTOLOGY
# 4    CHANDLER   34   94000           IT
#          Name  Age  Salary
# 1    MONICA     35   93000
# 3    ROSS       33  120000
# 4    CHANDLER   34   94000
