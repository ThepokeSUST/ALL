# %% [markdown]
# # Concat

# %%
import pandas as pd

data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}

df1 = pd.DataFrame(data1, index=[0, 1, 2, 3])

df2 = pd.DataFrame(data2, index=[4, 5, 6, 7])

print(df1, "\n\n", df2)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
frames=(df1,df2)
print(frames)
print()
res=pd.concat(frames)
print(res)
# Out:
# (     Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd,      Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons)
#
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
import pandas as pd

data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd'],
         'Mobile No': [97, 91, 58, 76]}

data2 = {'Name': ['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'],
         'Age': [22, 32, 12, 52],
         'Address': ['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
         'Qualification': ['MCA', 'Phd', 'Bcom', 'B.hons'],
         'Salary': [1000, 2000, 3000, 4000]}

df = pd.DataFrame(data1, index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[2, 3, 6, 7])

print(df, "\n\n", df1)
frames=[df,df1]
print()
res=pd.concat(frames,ignore_index=True,axis=0)
print(res)
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0     NaN
# 3    Anuj   32    Kannuaj           Phd       76.0     NaN
# 4  Gaurav   22  Allahabad           MCA        NaN  1000.0
# 5    Anuj   32    Kannuaj           Phd        NaN  2000.0
# ...

# %%
print(df, "\n\n", df1,end='\n\n')
frames=[df,df1]
res=pd.concat(frames,join="inner",sort=True,ignore_index=True,axis=0)
print(res)
# Out:
#     name  age dept
# 4      A   23  cse
# z      B   34  eee
# 0      C   54  swe
# 677    D   43  pme
#
#    name  age dept
# a   AA  232  cse
# b   BB  342  eee
# c   CC  542  swe
# d   DD  432  pme
#
#    age dept name
# 0   23  cse    A
# 1   34  eee    B
# 2   54  swe    C
# 3   43  pme    D
# 4  232  cse   AA
# 5  342  eee   BB
# 6  542  swe   CC
# 7  432  pme   DD

# %%
print(df, "\n\n", df1,end='\n\n')
frames=[df,df1]
res=pd.concat(frames,axis=1,ignore_index=False,join='inner')
print(res)
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#
#      Name  Age    Address Qualification  Mobile No    Name  Age    Address  \
# 2  Gaurav   22  Allahabad           MCA         58  Gaurav   22  Allahabad
# 3    Anuj   32    Kannuaj           Phd         76    Anuj   32    Kannuaj
#
#   Qualification  Salary
# 2           MCA    1000
# 3           Phd    2000

# %%
print(df, "\n\n", df1,end='\n\n')
frames=[df,df1]
res=pd.concat(frames,axis=1,join='outer')
print(res)
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#
#      Name   Age    Address Qualification  Mobile No    Name   Age    Address  \
# 0     Jai  27.0     Nagpur           Msc       97.0     NaN   NaN        NaN
# 1  Princi  24.0     Kanpur            MA       91.0     NaN   NaN        NaN
# 2  Gaurav  22.0  Allahabad           MCA       58.0  Gaurav  22.0  Allahabad
# 3    Anuj  32.0    Kannuaj           Phd       76.0    Anuj  32.0    Kannuaj
# 6     NaN   NaN        NaN           NaN        NaN  Dhiraj  12.0  Allahabad
# ...

# %%
df.index=[0,1,3,2]
df1.index=[2,3,6,7]
print(df, "\n\n", df1)
frames=[df,df1]
res=pd.concat(frames,axis=1,join='inner',sort=True)
print(res)
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 3  Gaurav   22  Allahabad           MCA         58
# 2    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#      Name  Age    Address Qualification  Mobile No    Name  Age    Address  \
# 2    Anuj   32    Kannuaj           Phd         76  Gaurav   22  Allahabad
# 3  Gaurav   22  Allahabad           MCA         58    Anuj   32    Kannuaj
#
#   Qualification  Salary
# 2           MCA    1000
# 3           Phd    2000

# %%
data={
    "name":['A','B','C','D'],
    'age':[23,34,54,43],
    'dept':['cse','eee','swe','pme']
    
}

df=pd.DataFrame(data)
df.index=[4,3,0,6]
print(df)

data1={
     "name":['AA','BB','CC','DD'],
    'age':[232,342,542,432],
    'dept':['cse','eee','swe','pme']
}
df1=pd.DataFrame(data1)
print(df1)

frame=[df,df1]
print()
res=pd.concat(frame,axis=1,sort=True,ignore_index=False)
print(res)
# Out:
#   name  age dept
# 4    A   23  cse
# 3    B   34  eee
# 0    C   54  swe
# 6    D   43  pme
#   name  age dept
# 0   AA  232  cse
# 1   BB  342  eee
# 2   CC  542  swe
# 3   DD  432  pme
#
#   name   age dept name    age dept
# 0    C  54.0  swe   AA  232.0  cse
# 1  NaN   NaN  NaN   BB  342.0  eee
# 2  NaN   NaN  NaN   CC  542.0  swe
# 3    B  34.0  eee   DD  432.0  pme
# 4    A  23.0  cse  NaN    NaN  NaN
# 6    D  43.0  pme  NaN    NaN  NaN

# %%
data={
    "name":['A','B','C','D'],
    'age':[23,34,54,43],
    'dept':['cse','eee','swe','pme']
    
}

df=pd.DataFrame(data)
df.index=[4,'z',0,677]
# print(df)

data1={
     "name":['AA','BB','CC','DD'],
    'age':[232,342,542,432],
    'dept':['cse','eee','swe','pme']
}
df1=pd.DataFrame(data1)
df1.index=['a','b','c','d']
print(df1)

frame=[df,df1]
print()
res=pd.concat(frame,axis=1,sort=True,ignore_index=False)
print(res)
print("\n\n")
res.reset_index(inplace=True,drop=True)
print(res)
# Out:
#   name  age dept
# a   AA  232  cse
# b   BB  342  eee
# c   CC  542  swe
# d   DD  432  pme
#
#     name   age dept name    age dept
# 0      C  54.0  swe  NaN    NaN  NaN
# 4      A  23.0  cse  NaN    NaN  NaN
# 677    D  43.0  pme  NaN    NaN  NaN
# a    NaN   NaN  NaN   AA  232.0  cse
# b    NaN   NaN  NaN   BB  342.0  eee
# c    NaN   NaN  NaN   CC  542.0  swe
# d    NaN   NaN  NaN   DD  432.0  pme
# z      B  34.0  eee  NaN    NaN  NaN
#
#
#
#   name   age dept name    age dept
# 0    C  54.0  swe  NaN    NaN  NaN
# 1    A  23.0  cse  NaN    NaN  NaN
# 2    D  43.0  pme  NaN    NaN  NaN
# 3  NaN   NaN  NaN   AA  232.0  cse
# 4  NaN   NaN  NaN   BB  342.0  eee
# 5  NaN   NaN  NaN   CC  542.0  swe
# 6  NaN   NaN  NaN   DD  432.0  pme
# 7    B  34.0  eee  NaN    NaN  NaN

# %%
data={
    "name":['A','B','C','D'],
    'age':[23,34,54,43],
    'dept':['cse','eee','swe','pme']
    
}

df=pd.DataFrame(data)
df.index=[4,3,1,6]
print(df)

lst=[1,2,3,4]
series=pd.Series([1,2,3,4],name='dp')
print(series)
res=pd.concat([df,series],axis=1,sort=True)
print(res)
# Out:
#   name  age dept
# 4    A   23  cse
# 3    B   34  eee
# 1    C   54  swe
# 6    D   43  pme
# 0    1
# 1    2
# 2    3
# 3    4
# Name: dp, dtype: int64
#   name   age dept   dp
# 0  NaN   NaN  NaN  1.0
# 1    C  54.0  swe  2.0
# 2  NaN   NaN  NaN  3.0
# 3    B  34.0  eee  4.0
# 4    A  23.0  cse  NaN
# 6    D  43.0  pme  NaN

# %% [markdown]
# # with key

# %%
import pandas as pd

data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}

data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
        'Age':[17, 14, 12, 52],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}

df = pd.DataFrame(data1,index=[0, 1, 2, 3])

df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])

# print(df, "\n\n", df1)

frames = [df, df1,df ]

res = pd.concat(frames, keys=['x', 'y',''])
res
# Out:
#        Name  Age    Address Qualification
# x 0     Jai   27     Nagpur           Msc
#   1  Princi   24     Kanpur            MA
#   2  Gaurav   22  Allahabad           MCA
#   3    Anuj   32    Kannuaj           Phd
# y 4    Abhi   17     Nagpur         Btech
#   5  Ayushi   14     Kanpur           B.A
#   6  Dhiraj   12  Allahabad          Bcom
#   7  Hitesh   52    Kannuaj        B.hons
#   0     Jai   27     Nagpur           Msc
#   1  Princi   24     Kanpur            MA
#   2  Gaurav   22  Allahabad           MCA
#   3    Anuj   32    Kannuaj           Phd

# %% [markdown]
# # dataframe and series

# %%
data={
    "name":['A','B','C','D'],
    'age':[23,34,54,43],
    'dept':['cse','eee','swe','pme']
    
}

df=pd.DataFrame(data)
df.index=[4,3,1,6]
print(df)

lst=[1,2,3,4]
series=pd.Series([1,2,3,4],name="age")
print(series)
res=pd.concat([df,series],sort=False,ignore_index=True)
print(res)
# Out:
#   name  age dept
# 4    A   23  cse
# 3    B   34  eee
# 1    C   54  swe
# 6    D   43  pme
# 0    1
# 1    2
# 2    3
# 3    4
# Name: age, dtype: int64
#   name   age dept    0
# 0    A  23.0  cse  NaN
# 1    B  34.0  eee  NaN
# 2    C  54.0  swe  NaN
# 3    D  43.0  pme  NaN
# 4  NaN   NaN  NaN  1.0
# 5  NaN   NaN  NaN  2.0
# 6  NaN   NaN  NaN  3.0
# 7  NaN   NaN  NaN  4.0
