# %% [markdown]
# # This is for learning pandas Data Frame

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame()

lst=np.array([12,22,33,44])
df=pd.DataFrame(lst)
print(df)
# Out:
#     0
# 0  12
# 1  22
# 2  33
# 3  44

# %% [markdown]
# S
